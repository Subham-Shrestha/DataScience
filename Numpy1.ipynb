# %%
import numpy as np

# %%
a = np.array([1,2,3,4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b = np.array([1,2,3.00])

# %%
b
# Out:
# array([1., 2., 3.])

# %%
c = np.array([1.0,2.0,3.0], dtype = 'int')

# %%
c
# Out:
# array([1, 2, 3])

# %%
d = np.array([1.9,2,3.0], dtype = 'int')

# %%
d
# Out:
# array([1, 2, 3])

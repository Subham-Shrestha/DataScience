# %%
import pandas as pd
pandas.__version__
# Out:
# '2.2.2'

# %%
pandas.__version__
# Out:
# '2.2.2'

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(5)
# Out:
# 0    5
# dtype: int64

# %%
pd.Series([1,2,3], dtype = 'int16')
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int16

# %%
pd.Series(10, index = ['a'])
# Out:
# a    10
# dtype: int64

# %%
pd.Series([3,4,5,6], index = ['a','b','c','d'])
# Out:
# a    3
# b    4
# c    5
# d    6
# dtype: int64

# %%
pd.Series([3, 4, 5, 6], index = ['a', 'b', 'a', 'b'])
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
a = pd.Series([1,2,3, pd.NA, pd.NA])

# %%
a
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# 4    <NA>
# dtype: object

# %%
a + 5
# Out:
# 0       6
# 1       7
# 2       8
# 3    <NA>
# 4    <NA>
# dtype: object

# %%
a = pd.Series([1,2,3])
b = pd.Series([4,5,6])

# %%
a+b
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
a = pd.Series([1,2,3])
b = pd.Series([4,5,6,7])

# %%
a+b
# Out:
# 0    5.0
# 1    7.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
my_series = pd.Series([3,4,5,6], index = ['a','b','a','b'])

# %%
my_series
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
my_series.index
# Out:
# Index(['a', 'b', 'a', 'b'], dtype='object')

# %%
my_series.values
# Out:
# array([3, 4, 5, 6])

# %%
my_series.values
# Out:
# array([3, 4, 5, 6])

# %%
my_series.dtype
# Out:
# dtype('int64')

# %%
my_series.shape
# Out:
# (4,)

# %%
my_series.size
# Out:
# 4

# %%
my_series.nbytes
# Out:
# 32

# %%
my_series.ndim
# Out:
# 1

# %%
my_series.T
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
my_series.memory_usage()
# Out:
# 236

# %%
my_series.hasnans
# Out:
# False

# %%
a = pd.Series([1,2,3,4, pd.NA])

# %%
a.hasnans
# Out:
# True

# %%
a.empty
# Out:
# False

# %%
a = pd.Series([])

# %%
a.empty
# Out:
# True
